# %%
import psycopg2
engine = psycopg2.connect(
    dbname="datos2",
    user="postgres",
    password="password",
    host="isabel.cvcju9aqozqq.us-east-1.rds.amazonaws.com",
    port='5432'
)

# %%
cursor = engine.cursor()

# %%
query = """
SELECT  *
FROM variables;"""
cursor.execute(query)
result = cursor.fetchall()
result
# Out:
# [(1,
#   'discom',
#   'basic',
#   'technicians',
#   Decimal('1'),
#   10.8,
#   'Dropout',
#   '17-28',
#   '0-4'),
#  (2,
#   'turismo',
#   'secundary',
#   'technicians',
#   Decimal('0'),
#   13.9,
#   'Graduate',
#   '17-28',
#   '12-16'),
#  (3,
#   'discom',
#   'basic',
#   'industry',
#   Decimal('0'),
#   10.8,
#   'Dropout',
#   '17-28',
#   '0-4'),
#  (4,
#   'discom',
#   'basic',
#   'technicians',
#   Decimal('1'),
#   9.4,
#   'Graduate',
#   '17-28',
#   '12-16'),
#  (5,
#   'soced',
#   'basic',
#   'industry',
#   Decimal('1'),
#   13.9,
#   'Graduate',
#   '39-50',
#   '12-16'),
#  (6,
#   'discom',
#   'basic',
#   'industry',
#   Decimal('1'),
#   16.2,
#   'Graduate',
#   '50-61',
#   '8-12'),
#  (7,
#   'salud',
#   'basic',
#   'industry',
#   Decimal('1'),
#   15.5,
#   'Graduate',
#   '17-28',
#   '12-16'),
#  (8,
#   'turismo',
#   'basic',
#   'industry',
#   Decimal('0'),
#   15.5,
#   'Dropout',
#   '17-28',
#   '0-4'),
#  (9,
#   'soced',
# ...
